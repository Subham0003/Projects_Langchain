# %%
import os 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
repo_id="mistralai/Mistral-7B-Instruct-v0.3"
llm=HuggingFaceEndpoint(repo_id=repo_id,temperature=0.7,huggingfacehub_api_token=os.getenv("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"))

# %%
llm
# Out:
# HuggingFaceEndpoint(repo_id='mistralai/Mistral-7B-Instruct-v0.3', temperature=0.7, model='mistralai/Mistral-7B-Instruct-v0.3', client=<InferenceClient(model='mistralai/Mistral-7B-Instruct-v0.3', timeout=120)>, async_client=<InferenceClient(model='mistralai/Mistral-7B-Instruct-v0.3', timeout=120)>)

# %%
llm.invoke("what is the companay called tcs")
# Out:
# " that is doing the programming for the new airport in Austin?\n\nThe company Tata Consultancy Services (TCS) is providing IT services for the new airport in Austin, Texas. However, it's important to note that TCS is typically involved in various aspects of IT and technology consulting, including software development, and they might be working on several projects within the airport's infrastructure development, not just the programming for the entire airport. For more specific details, I would recommend reaching out to the airport or TCS directly for accurate and detailed information."

# %%
from langchain import PromptTemplate,LLMChain
temp="""
Question:{question}
Answer:Lets think step by step.
"""
prompt=PromptTemplate(template=temp,input_variables=['questions'])
prompt
# Out:
# PromptTemplate(input_variables=['question'], template='\nQuestion:{question}\nAnswer:Lets think step by step.\n')

# %%
llm_chain=LLMChain(llm=llm,prompt=prompt)

# %%
llm_chain.invoke("who is the father of ai")
# Out:
# {'question': 'who is the father of ai',
#  'text': '\nArtificial Intelligence (AI) is a field of computer science that deals with creating machines that can mimic intelligent human behavior. AI was not born to a human parent. Instead, it was developed by many scientists, engineers, and researchers over several decades.\n\nSome of the key figures in the development of AI include Alan Turing, John McCarthy, Marvin Minsky, and others. They laid the groundwork for AI by creating concepts, theories, and algorithms that have been further developed and refined over the years. So, in a way, you could say that these pioneers are the "parents" of AI, but not in a biological sense.'}

# %%
from langchain_community.embeddings import HuggingFaceBgeEmbeddings

model_name = "BAAI/bge-small-en"
model_kwargs = {"device": "cpu"}
encode_kwargs = {"normalize_embeddings": True}
hf = HuggingFaceBgeEmbeddings(
    model_name=model_name, model_kwargs=model_kwargs, encode_kwargs=encode_kwargs
)
# Out:
# WARNING:tensorflow:From d:\Project\myenv\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
embeding=hf.embed_query("Hy i am subham")

# %%
embeding
# Out:
# [-0.0015211531426757574,
#  -0.018291112035512924,
#  0.008356437087059021,
#  -0.017820464447140694,
#  0.03460945188999176,
#  0.032446231693029404,
#  0.02750294655561447,
#  -0.014651485718786716,
#  -0.02691546455025673,
#  0.014433009549975395,
#  -0.019709134474396706,
#  -0.08874030411243439,
#  0.034980710595846176,
#  0.019613198935985565,
#  -0.009327089414000511,
#  -0.012024505995213985,
#  0.01126229390501976,
#  -0.0036659855395555496,
#  -0.013189482502639294,
#  0.050609324127435684,
#  -0.00980999693274498,
#  -0.022142626345157623,
#  -0.014373186975717545,
#  -0.029761696234345436,
#  0.02662973664700985,
#  0.034492846578359604,
#  -0.02880760282278061,
#  0.009079056791961193,
#  -0.04477085918188095,
#  -0.19013617932796478,
#  0.05808605998754501,
#  -0.020337147638201714,
#  0.029642872512340546,
#  0.026437900960445404,
#  0.027378644794225693,
#  -0.03241509571671486,
#  -0.03155694901943207,
#  0.029375283047556877,
#  -0.013990400359034538,
# ...
